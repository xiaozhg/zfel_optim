# %% [markdown]
# 1.Import packages

# %%
import pandas as pd
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.io
import random
import datetime
import time
#from zfel import sase1d_input_part
import sase1d_input_part
import torch
import torch.optim as optim

# %% [markdown]
# 2.Input parameters

# %%
Nruns=1                             # Number of runs
npart   = 512                       # n-macro-particles per bucket 
s_steps = 31#200#31                    # n-sample points along bunch length
z_steps = 20#200#20                    # n-sample points along undulator
energy  = 4313.34*1E6               # electron energy [eV]
eSpread = 0#1.0e-4                  # relative rms energy spread [ ]
emitN   = 1.2e-6                    # normalized transverse emittance [m-rad]
currentMax = 3900                   # peak current [Ampere]
beta = 26                           # mean beta [meter]
unduPeriod = 0.03                   # undulator period [meter]
#unduK = 3.5                        # undulator parameter, K [ ]
unduK = np.ones(z_steps)*3.5  # tapered undulator parameter, K [ ]
if unduK.shape[0]!=z_steps:
    print('Wrong! Number of steps should always be the same as z_steps')
unduL = 70#30                       # length of undulator [meter]
radWavelength = 1.5e-9              # seed wavelength? [meter], used only in single-freuqency runs
dEdz = 0                            # rate of relative energy gain or taper [keV/m], optimal~130
iopt = 'sase'                       # 'sase' or 'seeded'
P0 = 10000*0.0                      # small seed input power [W]
constseed = 1                       # whether we want to use constant random seed for reproducibility, 1 Yes, 0 No
particle_position=genfromtxt('./Inputs/particle_position.csv', delimiter=',') # or None  
# particle information with positions in meter and eta,\
# if we want to load random particle positions and energy, then set None
hist_rule='square-root'             # 'square-root' or 'sturges' or 'rice-rule' or 'self-design', number \
                                    #  of intervals to generate the histogram of eta value in a bucket

# %%
'''
Put input parameters into a inp_struct dict, for 1D FEL run
'''
inp_struct={'Nruns':Nruns,'npart':npart,'s_steps':s_steps,'z_steps':z_steps,'energy':energy,'eSpread':eSpread,\
            'emitN':emitN,'currentMax':currentMax,'beta':beta,'unduPeriod':unduPeriod,'unduK':unduK,'unduL':\
            unduL,'radWavelength':radWavelength,'dEdz':dEdz,'iopt':iopt,'P0':P0,'constseed':constseed,'particle_position':particle_position,'hist_rule':hist_rule}

# %% [markdown]
# 3.1D FEL run

# %% [markdown]
# Method 1: allow exploring all taper values

# %%
# %load_ext autoreload
# %autoreload

unduK = np.ones(z_steps)*3.5 #np.arange(3.52,3.48,-0.04/(z_steps-1))#   # tapered undulator parameter, K [ ]
if unduK.shape[0]!=z_steps:
    print('Wrong! Number of steps should always be the same as z_steps')
unduK_1=torch.tensor(unduK[:int(z_steps/2)],dtype=torch.float64)
unduK_2=torch.tensor(unduK[int(z_steps/2):],dtype=torch.float64,requires_grad=True)
#unduK = torch.tensor(unduK, dtype=torch.float64, requires_grad=True)
#undu_K=torch.cat((unduK_1,unduK_2))
#params_K = unduK
#learning_rate = 5e-21
#optimizer = optim.SGD([unduK_2], lr=learning_rate)
lr = 5e-21*torch.arange(unduK_2.shape[0])**4
n_epochs = 3000
his_FEL_power=[]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of sase1d_input_part failed: Traceback (most recent call last):
#   File "/Users/xiao/miniconda3/envs/gnn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/xiao/miniconda3/envs/gnn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/xiao/miniconda3/envs/gnn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/xiao/miniconda3/envs/gnn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/xiao/miniconda3/envs/gnn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/xiao/miniconda3/envs/gnn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/xiao/miniconda3/envs/gnn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/xiao/miniconda3/envs/gnn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/xiao/miniconda3/envs/gnn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/xiao/miniconda3/envs/gnn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]

# %%
def training_loop(n_epochs, lr, unduK_1, unduK_2, his_FEL_power):
    for epoch in range(1, n_epochs + 1):
        print('epochs:',epoch)
        '''
        Use sase function in sase1d.py to run 1D FEL
        '''
        #with torch.autograd.set_detect_anomaly(True):
        #inp_struct['unduK']=params_K
        if unduK_2.grad is not None:
            unduK_2.grad.zero_()
        undu_K=torch.cat((unduK_1,unduK_2))
        inp_struct['unduK']=undu_K
        z,power_z,s,power_s,rho,detune,field,\
        field_s,gainLength,resWavelength,\
        thet_out,eta_out,bunching,spectrum,freq,\
        Ns,history=sase1d_input_part.sase(inp_struct)
        power_z[-1].backward()
        print('gradient',unduK_2.grad)
        unduK_2=(unduK_2 - lr * \
            unduK_2.grad).detach().requires_grad_()
        
        #optimizer.zero_grad()
        #power_z[-1].backward()
        #optimizer.step()
        #print('gradient',unduK_2.grad)
        
        his_FEL_power.append(power_z[-1].detach().numpy())
    undu_K=torch.cat((unduK_1,unduK_2))
    return undu_K, his_FEL_power

# %%
undu_K, his_FEL_power= training_loop(
    n_epochs = n_epochs,
    lr       = lr,
    #optimizer = optimizer,
    unduK_1 = unduK_1,
    unduK_2 = unduK_2,
    his_FEL_power = his_FEL_power)
# Out:
# epochs: 1
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-1.5772e+19, -5.0989e+17, -2.7386e+17, -9.0223e+16,  4.7750e+16,
#         -4.5824e+15, -1.9328e+15, -1.1399e+15,  9.1002e+13,  0.0000e+00],
#        dtype=torch.float64)
# epochs: 2
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.5025, 3.5219, 3.5365, 3.4389, 3.5143, 3.5125, 3.5137,
#         3.4981, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-3.6170e+18,  3.4863e+18,  6.5433e+17,  5.3639e+16, -2.6594e+16,
#         -1.8817e+16, -1.5253e+15, -9.5440e+14,  9.8209e+13,  9.4367e-04],
#        dtype=torch.float64)
# epochs: 3
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4851, 3.4696, 3.5148, 3.4729, 3.5731, 3.5224, 3.5251,
#         3.4961, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 1.3775e+19,  2.1194e+17,  1.2344e+18, -1.7088e+17, -4.5093e+16,
#         -1.8150e+16,  6.3871e+15,  1.2825e+15, -1.6398e+14,  0.0000e+00],
#        dtype=torch.float64)
# epochs: 4
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4841, 3.3708, 3.5840, 3.5306, 3.6298, 3.4810, 3.5097,
#         3.4995, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 1.2863e+19,  4.5392e+18, -1.0120e+18, -3.4236e+17, -1.0384e+17,
#         -9.2979e+15, -8.0976e+15,  1.5409e+14, -1.2121e+14,  1.8216e-03],
#        dtype=torch.float64)
# epochs: 5
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4614, 3.4518, 3.7227, 3.6636, 3.6589, 3.5335, 3.5079,
#         3.5020, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 9.6632e+18,  1.0644e+18,  5.0336e+17, -4.5494e+16, -6.1461e+15,
#         -1.5926e+16, -1.5065e+15,  2.2242e+14, -6.8887e+13, -1.8873e-03],
#        dtype=torch.float64)
# epochs: 6
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4560, 3.4115, 3.7411, 3.6714, 3.7087, 3.5433, 3.5052,
#         3.5034, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-6.1015e+18,  9.8189e+17,  6.6308e+17,  2.3515e+17, -4.4658e+15,
#          2.8301e+15,  2.7948e+15, -5.1838e+14, -1.5812e+14,  0.0000e+00],
#        dtype=torch.float64)
# epochs: 7
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4511, 3.3585, 3.6459, 3.6771, 3.6998, 3.5251, 3.5114,
#         3.5066, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-1.3127e+19, -1.4186e+18, -1.0007e+18, -4.9087e+16,  1.6352e+16,
#          2.1000e+15, -1.8585e+15,  9.9263e+13,  2.4071e+14, -6.5785e-05],
#        dtype=torch.float64)
# epochs:
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4248, 4.2371, 2.8293, 4.0432, 3.3235, 3.5403, 3.5180,
#         3.4944, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-5.1829e+18,  9.5073e+17, -1.0226e+17, -2.1746e+17,  2.7074e+15,
#          1.0897e+16,  1.5871e+15, -4.8935e+14,  2.1851e+14,  1.3991e-03],
#        dtype=torch.float64)
# epochs: 85
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4200, 4.2453, 2.9173, 4.0397, 3.2894, 3.5300, 3.5239,
#         3.4899, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 2.5717e+18,  2.3718e+18,  1.0040e+18, -9.4290e+16, -8.4674e+15,
#          7.8314e+15,  5.9497e+15,  7.0591e+13, -1.7966e+11,  0.0000e+00],
#        dtype=torch.float64)
# epochs: 86
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4082, 4.1649, 2.9555, 4.0506, 3.2649, 3.4914, 3.5231,
#         3.4899, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-3.3596e+18,  1.1682e+18, -7.2346e+16, -2.5841e+16, -1.0941e+16,
#         -4.9135e+15,  3.8354e+14,  5.3753e+14,  2.2562e+14,  0.0000e+00],
#        dtype=torch.float64)
# epochs: 87
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4023, 4.1707, 2.9660, 4.0646, 3.2803, 3.4889, 3.5166,
#         3.4853, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 6.0095e+18, -2.2184e+17,  2.3964e+17, -3.4565e+17, -3.5633e+16,
#         -9.5877e+15, -1.0710e+15, -3.4452e+14,  3.0701e+14,  9.4367e-04],
#        dtype=torch.float64)
# epochs: 88
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4034, 4.1516, 3.1060, 4.1102, 3.3102, 3.4959, 3.5207,
#         3.4790, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-5.0305e+18, -4.9642e+18,  1.5169e+17, -2.7043e+16, -4.3888e+14,
#          6.1011e+15,  1.4602e+15, -5.1654e+14, -5.5452e+14,  9.4367e-04],
#        dtype=torch.float64)
# epochs: 89
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4282, 4.1394, 3.1169, 4.1108, 3.2912, 3.4864, 3.5269,
#         3.4904, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 1.1330e+19,  1.3483e+18, -2.0377e+17, -9.0727e+15,  3.7979e+16,
#         -7.7472e+15,  4.4540e+15, -4.4631e+14,  1.4106e+14,  0.0000e+00],
#        dtype=torch.float64)
# epochs: 90
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4215, 4.1557, 3.1206, 4.0621, 3.3154, 3.4576, 3.5323,
#         3.4875, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 3.9783e+18, -4.0568e+17,  6.1766e+16,  1.4088e+17, -1.7076e+16,
#         -3.6828e+15, -8.9231e+14, -5.5705e+14,  7.4125e+13,  4.5539e-04],
#        dtype=torch.float64)
# epochs: 91
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4235, 4.1508, 3.0636, 4.0840, 3.3269, 3.4633, 3.5390,
#         3.4860, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 4.5520e+18,  1.1069e+15, -2.3151e+17, -9.7299e+15,  1.7933e+16,
#         -8.8952e+15, -1.3010e+15,  4.6522e+14,  2.1542e+14,  0.0000e+00],
#        dtype=torch.float64)
# epochs: 92
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4235, 4.1693, 3.0675, 4.0611, 3.3547, 3.4718, 3.5334,
#         3.4815, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 2.9523e+18, -3.1092e+17,  2.0323e+15, -6.5867e+16, -8.6419e+15,
#          2.2703e+15, -2.2034e+15,  7.3097e+14,  7.6259e+13, -3.2893e-05],
#        dtype=torch.float64)
# epochs: 93
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4251, 4.1691, 3.0942, 4.0721, 3.3476, 3.4860, 3.5246,
#         3.4800, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 5.7659e+17, -2.4384e+18, -4.4263e+17,  2.8752e+17,  2.6217e+16,
#          1.9395e+16, -3.1325e+15,  5.4363e+14, -1.5922e+14,  9.1078e-04],
#        dtype=torch.float64)
# epochs: 94
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 3.4373, 4.2045, 2.9777, 4.0386, 3.2870, 3.5063, 3.5181,
#         3.4832, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8371, 2.6141, 5.4419, 4.1714, 4.5143, 4.0294, 3.4593,
#         3.2978, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 6.2547e+18, -1.2755e+17,  1.5893e+18,  1.7865e+17, -7.2446e+15,
#          1.9513e+15,  3.3644e+14, -6.9211e+13,  3.5345e+13,  0.0000e+00],
#        dtype=torch.float64)
# epochs: 491
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8377, 2.4870, 5.3696, 4.1806, 4.5082, 4.0273, 3.4602,
#         3.2971, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 1.2560e+18,  1.5521e+18,  8.0726e+17,  2.2076e+17,  5.1939e+16,
#          4.0981e+15,  3.0937e+15, -6.8265e+14,  2.6687e+14,  4.8828e-04],
#        dtype=torch.float64)
# epochs: 492
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8299, 2.4224, 5.2802, 4.1142, 4.4954, 4.0072, 3.4683,
#         3.2916, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-1.6075e+17,  1.5444e+18,  1.8535e+18, -1.2101e+17, -8.0626e+16,
#         -3.0699e+14, -1.0728e+15, -1.0178e+15, -2.3847e+14,  9.1078e-04],
#        dtype=torch.float64)
# epochs: 493
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8222, 2.2741, 5.3292, 4.2174, 4.4964, 4.0142, 3.4806,
#         3.2965, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 8.5851e+18, -5.6431e+16, -1.5736e+18,  8.0773e+16, -2.9243e+16,
#          1.0445e+16,  7.7688e+14,  1.3598e+14,  3.1831e+14,  9.1078e-04],
#        dtype=torch.float64)
# epochs: 494
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8225, 2.4000, 5.2964, 4.2548, 4.4637, 4.0091, 3.4789,
#         3.2900, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 1.6619e+18, -1.4824e+17, -8.1720e+15, -1.8884e+17,  4.9193e+16,
#         -5.5415e+15, -3.1023e+15, -6.6655e+14, -2.5218e+14,  9.1078e-04],
#        dtype=torch.float64)
# epochs: 495
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8232, 2.4007, 5.3729, 4.1918, 4.4811, 4.0292, 3.4869,
#         3.2952, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 4.0320e+18, -9.6604e+18,  6.9577e+17, -2.5747e+17,  1.2525e+17,
#          3.2985e+16,  1.7090e+15,  8.1859e+13,  4.9050e+13,  9.1078e-04],
#        dtype=torch.float64)
# epochs: 496
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8716, 2.3450, 5.4772, 4.0315, 4.3780, 4.0182, 3.4860,
#         3.2942, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-1.3309e+17, -1.6095e+18,  2.6313e+18,  1.3250e+16,  6.0542e+14,
#          8.2701e+15, -4.0303e+14,  2.0760e+14, -3.0859e+14,  4.8828e-04],
#        dtype=torch.float64)
# epochs: 497
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8796, 2.1345, 5.4718, 4.0307, 4.3521, 4.0208, 3.4835,
#         3.3005, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 7.7170e+18,  4.3570e+18,  3.3953e+18,  7.9678e+16,  8.3374e+16,
#         -2.0922e+15, -4.1344e+14, -7.7447e+14,  1.0461e+14,  0.0000e+00],
#        dtype=torch.float64)
# epochs: 498
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8578, 1.8629, 5.4396, 3.9240, 4.3587, 4.0235, 3.4928,
#         3.2983, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([ 3.7418e+18,  2.9809e+18, -1.0097e+18, -1.6434e+17,  2.7781e+16,
#          5.7560e+15, -2.6210e+15, -1.8214e+14,  3.1501e+14, -1.3157e-04],
#        dtype=torch.float64)
# epochs: 499
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8429, 1.9437, 5.5061, 3.8885, 4.3407, 4.0404, 3.4949,
#         3.2919, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-1.3344e+19,  4.7366e+18,  3.1884e+17, -9.2505e+14,  3.4533e+15,
#          6.3602e+15,  5.9008e+15,  2.1618e+14,  2.5570e+14,  9.7656e-04],
#        dtype=torch.float64)
# epochs: 500
# undu tensor([3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000, 3.5000,
#         3.5000, 3.5000, 2.8192, 1.9182, 5.5065, 3.8840, 4.3208, 4.0022, 3.4923,
#         3.2867, 3.5000], dtype=torch.float64, grad_fn=<CatBackward>)
# gradient tensor([-1.2425e+19, -3.1863e+17, -1.2032e+18, -1.3281e+17,  4.2167e+16,
#          1.7055e+16, -1.3052e+15,  1.0599e+14, -4.2984e+14,  0.0000e+00],
#        dtype=torch.float64)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-b1afd9825b10> in <module>
#       5     unduK_1 = unduK_1,
#       6     unduK_2 = unduK_2,
# ----> 7     his_FEL_power = his_FEL_power)
#
# <ipython-input-116-4651464cd9a1> in training_loop(n_epochs, lr, unduK_1, unduK_2, his_FEL_power)
#      28
#      29         if epoch % 500 == 0:
# ---> 30             print('Epoch %d, Loss %f' % (epoch, float(loss)))
#      31     undu_K=torch.cat((unduK_1,unduK_2))
#      32     return undu_K, his_FEL_power
#
# NameError: name 'loss' is not defined

# %%
plt.figure()
plt.plot(undu_K.detach().numpy())
plt.title('final taper value')
plt.figure()
plt.plot(his_FEL_power,'.-')
plt.title('output FEL power vs. epochs')
# Out:
# Text(0.5, 1.0, 'output FEL power vs. epochs')

# %% [markdown]
# Method 2: fit to quadratic taper

# %%
# %load_ext autoreload
# %autoreload


#params_K=torch.tensor([2.3,-0.001],requires_grad=True)
const_K=torch.tensor(2.3,requires_grad=True)
param_K=torch.tensor(-0.001,requires_grad=True)
lr_const = 1e-17
lr_param = 1e-29
#optimizer = optim.SGD([params_K], lr=learning_rate)
n_epochs = 100
his_FEL_power=[]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def training_loop(n_epochs, const_K, param_K, lr_const, lr_param, z_steps, his_FEL_power):
    for epoch in range(1, n_epochs + 1):
        print('epochs:',epoch)
        '''
        Use sase function in sase1d.py to run 1D FEL
        '''
        if const_K.grad is not None:
            const_K.grad.zero_()
        if param_K.grad is not None:
            param_K.grad.zero_()
        #with torch.autograd.set_detect_anomaly(True):
        #inp_struct['unduK']=params_K
        #if unduK_2.grad is not None:
        #    unduK_2.grad.zero_()
        unduK_1=const_K*torch.ones(int(z_steps/2))
        unduK_2=const_K+param_K*torch.arange(z_steps-int(z_steps/2))**2
        undu_K=torch.cat((unduK_1,unduK_2))
        inp_struct['unduK']=undu_K
        z,power_z,s,power_s,rho,detune,field,\
        field_s,gainLength,resWavelength,\
        thet_out,eta_out,bunching,spectrum,freq,\
        Ns,history=sase1d_input_part.sase(inp_struct)
        
        
        #optimizer = optim.SGD([params_K], lr=lr)
        #optimizer.zero_grad()
        if epoch==1:
            power_z[-1].backward(retain_graph=True)
        else:
            power_z[-1].backward()
        print('gradient',const_K.grad,param_K.grad)
        const_K=(const_K - lr_const * const_K.grad).detach().requires_grad_()
        param_K=(param_K - lr_param * param_K.grad).detach().requires_grad_()
        #optimizer.step()
        
        print('power',power_z[-1])
        
        his_FEL_power.append(power_z[-1].detach().numpy())
    unduK_1=const_K*torch.ones(int(z_steps/2))
    unduK_2=const_K+param_K*torch.arange(z_steps-int(z_steps/2))**2
    undu_K=torch.cat((unduK_1,unduK_2))
    return undu_K, his_FEL_power

# %%
undu_K, his_FEL_power= training_loop(
    n_epochs = n_epochs,
    const_K = const_K,
    param_K = param_K,
    lr_const = lr_const,
    lr_param = lr_param,
    z_steps = z_steps,
    his_FEL_power = his_FEL_power)
# Out:
# epochs: 1
# undu tensor([2.3000, 2.3000, 2.3000, 2.3000, 2.3000, 2.3000, 2.3000, 2.3000, 2.3000,
#         2.3000, 2.3000, 2.2990, 2.2960, 2.2910, 2.2840, 2.2750, 2.2640, 2.2510,
#         2.2360, 2.2190], grad_fn=<CatBackward>)
# gradient tensor(-4.3766e+15) tensor(-3.1394e+15)
# power tensor(3.5975e+13, grad_fn=<SelectBackward>)
# epochs: 2
# undu tensor([2.3438, 2.3438, 2.3438, 2.3438, 2.3438, 2.3438, 2.3438, 2.3438, 2.3438,
#         2.3438, 2.3438, 2.3428, 2.3398, 2.3348, 2.3278, 2.3188, 2.3078, 2.2948,
#         2.2798, 2.2628], grad_fn=<CatBackward>)
# gradient tensor(2.7367e+15) tensor(1.3194e+17)
# power tensor(3.1966e+13, grad_fn=<SelectBackward>)
# epochs: 3
# undu tensor([2.3164, 2.3164, 2.3164, 2.3164, 2.3164, 2.3164, 2.3164, 2.3164, 2.3164,
#         2.3164, 2.3164, 2.3154, 2.3124, 2.3074, 2.3004, 2.2914, 2.2804, 2.2674,
#         2.2524, 2.2354], grad_fn=<CatBackward>)
# gradient tensor(4.9681e+15) tensor(-7.0077e+17)
# power tensor(3.5972e+13, grad_fn=<SelectBackward>)
# epochs: 4
# undu tensor([2.2667, 2.2667, 2.2667, 2.2667, 2.2667, 2.2667, 2.2667, 2.2667, 2.2667,
#         2.2667, 2.2667, 2.2657, 2.2627, 2.2577, 2.2507, 2.2417, 2.2307, 2.2177,
#         2.2027, 2.1857], grad_fn=<CatBackward>)
# gradient tensor(6.9357e+15) tensor(-1.0847e+18)
# power tensor(3.9747e+13, grad_fn=<SelectBackward>)
# epochs: 5
# undu tensor([2.1974, 2.1974, 2.1974, 2.1974, 2.1974, 2.1974, 2.1974, 2.1974, 2.1974,
#         2.1974, 2.1974, 2.1964, 2.1934, 2.1884, 2.1814, 2.1724, 2.1614, 2.1484,
#         2.1334, 2.1164], grad_fn=<CatBackward>)
# gradient tensor(-1.8188e+15) tensor(5.6678e+17)
# power tensor(3.3894e+13, grad_fn=<SelectBackward>)
# epochs: 6
# undu tensor([2.2155, 2.2155, 2.2155, 2.2155, 2.2155, 2.2155, 2.2155, 2.2155, 2.2155,
#         2.2155, 2.2155, 2.2146, 2.2115, 2.2065, 2.1995, 2.1905, 2.1795, 2.1665,
#         2.1516, 2.1345], grad_fn=<CatBackward>)
# gradient tensor(5.8934e+15) tensor(2.9401e+16)
# power tensor(3.7104e+13, grad_fn=<SelectBackward>)
# epochs: 7
# undu tensor([2.1566, 2.1566, 2.1566, 2.1566, 2.1566, 2.1566, 2.1566, 2.1566, 2.1566,
#         2.1566, 2.1566, 2.1556, 2.1526, 2.1476, 2.1406, 2.1316, 2.1206, 2.1076,
#         2.0926, 2.0756], grad_fn=<CatBackward>)
# gradient tensor(-7.0153e+15) tensor(-2.9273e+17)
# power tensor(4.4602e+13, grad_fn=<SelectBackward>)
# epochs: 8
# undu tensor([2.2268, 2.2268, 2.2268, 2.2268, 2.2268, 2.2268, 2.2268, 2.2268, 2.2268,
#         2.2268, 2.2268, 2.2258, 2.2228, 2.2178, 2.2108, 2.2018, 2.1908, 2.1778,
#         2.1628, 2.1458], grad_fn=<CatBackward>)
# gradient tensor(3.5739e+14) tensor(-3.2522e+17)
# power tensor(4.1318e+13, grad_fn=<SelectBackward>)
# epochs: 9
# undu tensor([2.2232, 2.2232, 2.2232, 2.2232, 2.2232, 2.2232, 2.2232, 2.2232, 2.2232,
#         2.2232, 2.2232, 2.2222, 2.2192, 2.2142, 2.2072, 2.1982, 2.1872, 2.1742,
#         2.1592, 2.1422], grad_fn=<CatBackward>)
# gradient tensor(4.9409e+14) tensor(-1.4505e+18)
# power tensor(3.9959e+13, grad_fn=<SelectBackward>)
# epochs: 10
# undu tensor([2.2183, 2.2183, 2.2183, 2.2183, 2.2183, 2.2183, 2.2183, 2.2183, 2.2183,
#         2.2183, 2.2183, 2.2173, 2.2143, 2.2093, 2.2023, 2.1933, 2.1823, 2.1693,
#         2.1543, 2.1373], grad_fn=<CatBackward>)
# gradient tensor(-1.3639e+14) tensor(1.3392e+18)
# power tensor(3.5432e+13, grad_fn=<SelectBackward>)
# epochs: 11
# undu tensor([2.2196, 2.2196, 2.2196, 2.2196, 2.2196, 2.2196, 2.2196, 2.2196, 2.2196,
#         2.2196, 2.2196, 2.2186, 2.2156, 2.2106, 2.2036, 2.1946, 2.1836, 2.1706,
#         2.1556, 2.1386], grad_fn=<CatBackward>)
# gradient tensor(1.8350e+16) tensor(1.9077e+18)
# power tensor(3.4821e+13, grad_fn=<SelectBackward>)
# epochs: 12
# undu tensor([2.0361, 2.0361, 2.0361, 2.0361, 2.0361, 2.0361, 2.0361, 2.0361, 2.0361,
#         2.0361, 2.0361, 2.0351, 2.0321, 2.0271, 2.0201, 2.0111, 2.0001, 1.9871,
#         1.9721, 1.9551], grad_fn=<CatBackward>)
# gradient tensor(2.0561e+15) tensor(1.5004e+18)
# power tensor(4.3261e+13, grad_fn=<SelectBackward>)
# epochs: 13
# undu tensor([2.0156, 2.0156, 2.0156, 2.0156, 2.0156, 2.0156, 2.0156, 2.0156, 2.0156,
#         2.0156, 2.0156, 2.0146, 2.0116, 2.0066, 1.9996, 1.9906, 1.9796, 1.9666,
#         1.9516, 1.9346], grad_fn=<CatBackward>)
# gradient tensor(-2.3497e+15) tensor(4.0759e+17)
# power tensor(4.2850e+13, grad_fn=<SelectBackward>)
# epochs: 14
# undu tensor([2.0391, 2.0391, 2.0391, 2.0391, 2.0391, 2.0391, 2.0391, 2.0391, 2.0391,
#         2.0391, 2.0391, 2.0381, 2.0351, 2.0301, 2.0231, 2.0141, 2.0031, 1.9901,
#         1.9751, 1.9581], grad_fn=<CatBackward>)
# gradient tensor(4.4970e+15) tensor(-3.8027e+17)
# power tensor(4.4451e+13, grad_fn=<SelectBackward>)
# epochs: 15
# undu tensor([1.9941, 1.9941, 1.9941, 1.9941, 1.9941, 1.9941, 1.9941, 1.9941, 1.9941,
#         1.9941, 1.9941, 1.9931, 1.9901, 1.9851, 1.9781, 1.9691, 1.9581, 1.9451,
#         1.9301, 1.9131], grad_fn=<CatBackward>)
# gradient tensor(-8.8428e+14) tensor(7.7028e+17)
# power tensor(4.0964e+13, grad_fn=<SelectBackward>)
# epochs: 16
# undu tensor([2.0029, 2.0029, 2.0029, 2.0029, 2.0029, 2.0029, 2.0029, 2.0029, 2.0029,
#         2.0029, 2.0029, 2.0019, 1.9989, 1.9939, 1.9869, 1.9779, 1.9669, 1.9539,
#         1.9389, 1.9219], grad_fn=<CatBackward>)
# gradient tensor(-6.3620e+14) tensor(3.0357e+17)
# power tensor(4.3789e+13, grad_fn=<SelectBackward>)
# epochs: 17
# undu tensor([2.0093, 2.0093, 2.0093, 2.0093, 2.0093, 2.0093, 2.0093, 2.0093, 2.0093,
#         2.0093, 2.0093, 2.0083, 2.0053, 2.0003, 1.9933, 1.9843, 1.9733, 1.9603,
#         1.9453, 1.9283], grad_fn=<CatBackward>)
# gradient tensor(1.8384e+15) tensor(-1.8901e+17)
# power tensor(4.4197e+13, grad_fn=<SelectBackward>)
# epochs: 18
# undu tensor([1.9909, 1.9909, 1.9909, 1.9909, 1.9909, 1.9909, 1.9909, 1.9909, 1.9909,
#         1.9909, 1.9909, 1.9899, 1.9869, 1.9819, 1.9749, 1.9659, 1.9549, 1.9419,
#         1.9269, 1.9099], grad_fn=<CatBackward>)
# gradient tensor(1.2561e+15) tensor(2.0257e+17)
# power tensor(4.5851e+13, grad_fn=<SelectBackward>)
# epochs: 19
# undu tensor([1.9783, 1.9783, 1.9783, 1.9783, 1.9783, 1.9783, 1.9783, 1.9783, 1.9783,
#         1.9783, 1.9783, 1.9773, 1.9743, 1.9693, 1.9623, 1.9533, 1.9423, 1.9293,
#         1.9143, 1.8973], grad_fn=<CatBackward>)
# gradient tensor(-3.0931e+14) tensor(5.1597e+17)
# power tensor(4.3840e+13, grad_fn=<SelectBackward>)
# epochs: 20
# undu tensor([1.9814, 1.9814, 1.9814, 1.9814, 1.9814, 1.9814, 1.9814, 1.9814, 1.9814,
#         1.9814, 1.9814, 1.9804, 1.9774, 1.9724, 1.9654, 1.9564, 1.9454, 1.9324,
#         1.9174, 1.9004], grad_fn=<CatBackward>)
# gradient tensor(1.8552e+15) tensor(1.0170e+17)
# power tensor(4.1497e+13, grad_fn=<SelectBackward>)
# epochs: 21
# undu tensor([1.9629, 1.9629, 1.9629, 1.9629, 1.9629, 1.9629, 1.9629, 1.9629, 1.9629,
#         1.9629, 1.9629, 1.9619, 1.9589, 1.9539, 1.9469, 1.9379, 1.9269, 1.9139,
#         1.8989, 1.8819], grad_fn=<CatBackward>)
# gradient tensor(-1.8609e+14) tensor(-1.8821e+16)
# power tensor(4.1843e+13, grad_fn=<SelectBackward>)
# epochs: 22
# undu tensor([1.9647, 1.9647, 1.9647, 1.9647, 1.9647, 1.9647, 1.9647, 1.9647, 1.9647,
#         1.9647, 1.9647, 1.9637, 1.9607, 1.9557, 1.9487, 1.9397, 1.9287, 1.9157,
#         1.9007, 1.8837], grad_fn=<CatBackward>)
# gradient tensor(-2.2326e+15) tensor(-1.1935e+18)
# power tensor(3.9068e+13, grad_fn=<SelectBackward>)
# epochs: 23
# undu tensor([1.9871, 1.9871, 1.9871, 1.9871, 1.9871, 1.9871, 1.9871, 1.9871, 1.9871,
#         1.9871, 1.9871, 1.9861, 1.9831, 1.9781, 1.9711, 1.9621, 1.9511, 1.9381,
#         1.9231, 1.9061], grad_fn=<CatBackward>)
# gradient tensor(-2.2141e+14) tensor(-1.0231e+17)
# power tensor(4.4686e+13, grad_fn=<SelectBackward>)
# epochs: 24
# undu tensor([1.9893, 1.9893, 1.9893, 1.9893, 1.9893, 1.9893, 1.9893, 1.9893, 1.9893,
#         1.9893, 1.9893, 1.9883, 1.9853, 1.9803, 1.9733, 1.9643, 1.9533, 1.9403,
#         1.9253, 1.9083], grad_fn=<CatBackward>)
# gradient tensor(-5.6123e+15) tensor(-3.4124e+17)
# power tensor(4.3534e+13, grad_fn=<SelectBackward>)
# epochs: 25
# undu tensor([2.0454, 2.0454, 2.0454, 2.0454, 2.0454, 2.0454, 2.0454, 2.0454, 2.0454,
#         2.0454, 2.0454, 2.0444, 2.0414, 2.0364, 2.0294, 2.0204, 2.0094, 1.9964,
#         1.9814, 1.9644], grad_fn=<CatBackward>)
# gradient tensor(-2.8902e+15) tensor(-1.6919e+18)
# power tensor(3.8683e+13, grad_fn=<SelectBackward>)
# epochs: 26
# undu tensor([2.0743, 2.0743, 2.0743, 2.0743, 2.0743, 2.0743, 2.0743, 2.0743, 2.0743,
#         2.0743, 2.0743, 2.0733, 2.0703, 2.0653, 2.0583, 2.0493, 2.0383, 2.0253,
#         2.0103, 1.9933], grad_fn=<CatBackward>)
# gradient tensor(-2.2590e+15) tensor(3.3614e+17)
# power tensor(4.6931e+13, grad_fn=<SelectBackward>)
# epochs: 27
# undu tensor([2.0969, 2.0969, 2.0969, 2.0969, 2.0969, 2.0969, 2.0969, 2.0969, 2.0969,
#         2.0969, 2.0969, 2.0959, 2.0929, 2.0879, 2.0809, 2.0719, 2.0609, 2.0479,
#         2.0329, 2.0159], grad_fn=<CatBackward>)
# gradient tensor(1.0471e+16) tensor(8.1304e+17)
# power tensor(4.4531e+13, grad_fn=<SelectBackward>)
# epochs: 28
# undu tensor([1.9922, 1.9922, 1.9922, 1.9922, 1.9922, 1.9922, 1.9922, 1.9922, 1.9922,
#         1.9922, 1.9922, 1.9912, 1.9882, 1.9832, 1.9762, 1.9672, 1.9562, 1.9432,
#         1.9282, 1.9112], grad_fn=<CatBackward>)
# gradient tensor(-2.3236e+15) tensor(-5.2221e+17)
# power tensor(4.2473e+13, grad_fn=<SelectBackward>)
# epochs: 29
# undu tensor([2.0154, 2.0154, 2.0154, 2.0154, 2.0154, 2.0154, 2.0154, 2.0154, 2.0154,
#         2.0154, 2.0154, 2.0144, 2.0114, 2.0064, 1.9994, 1.9904, 1.9794, 1.9664,
#         1.9514, 1.9344], grad_fn=<CatBackward>)
# gradient tensor(-1.9275e+15) tensor(-6.4200e+17)
# power tensor(4.3302e+13, grad_fn=<SelectBackward>)
# epochs: 30
# undu tensor([2.0347, 2.0347, 2.0347, 2.0347, 2.0347, 2.0347, 2.0347, 2.0347, 2.0347,
#         2.0347, 2.0347, 2.0337, 2.0307, 2.0257, 2.0187, 2.0097, 1.9987, 1.9857,
#         1.9707, 1.9537], grad_fn=<CatBackward>)
# gradient tensor(-6.4992e+15) tensor(1.1639e+18)
# power tensor(4.5336e+13, grad_fn=<SelectBackward>)
# epochs: 31
# undu tensor([2.0997, 2.0997, 2.0997, 2.0997, 2.0997, 2.0997, 2.0997, 2.0997, 2.0997,
#         2.0997, 2.0997, 2.0987, 2.0957, 2.0907, 2.0837, 2.0747, 2.0637, 2.0507,
#         2.0357, 2.0187], grad_fn=<CatBackward>)
# gradient tensor(1.9647e+15) tensor(1.2731e+18)
# power tensor(4.4773e+13, grad_fn=<SelectBackward>)
# epochs: 32
# undu tensor([2.0800, 2.0800, 2.0800, 2.0800, 2.0800, 2.0800, 2.0800, 2.0800, 2.0800,
#         2.0800, 2.0800, 2.0790, 2.0760, 2.0710, 2.0640, 2.0550, 2.0440, 2.0310,
#         2.0160, 1.9990], grad_fn=<CatBackward>)
# gradient tensor(5.6926e+15) tensor(-1.5049e+17)
# power tensor(4.6265e+13, grad_fn=<SelectBackward>)
# epochs: 33
# undu tensor([2.0231, 2.0231, 2.0231, 2.0231, 2.0231, 2.0231, 2.0231, 2.0231, 2.0231,
#         2.0231, 2.0231, 2.0221, 2.0191, 2.0141, 2.0071, 1.9981, 1.9871, 1.9741,
#         1.9591, 1.9421], grad_fn=<CatBackward>)
# gradient tensor(-3.7467e+15) tensor(-1.2368e+18)
# power tensor(4.2514e+13, grad_fn=<SelectBackward>)
# epochs: 34
# undu tensor([2.0606, 2.0606, 2.0606, 2.0606, 2.0606, 2.0606, 2.0606, 2.0606, 2.0606,
#         2.0606, 2.0606, 2.0596, 2.0566, 2.0516, 2.0446, 2.0356, 2.0246, 2.0116,
#         1.9966, 1.9796], grad_fn=<CatBackward>)
# gradient tensor(4.7238e+14) tensor(9.9461e+17)
# power tensor(3.7653e+13, grad_fn=<SelectBackward>)
# epochs: 35
# undu tensor([2.0559, 2.0559, 2.0559, 2.0559, 2.0559, 2.0559, 2.0559, 2.0559, 2.0559,
#         2.0559, 2.0559, 2.0549, 2.0519, 2.0469, 2.0399, 2.0309, 2.0199, 2.0069,
#         1.9919, 1.9749], grad_fn=<CatBackward>)
# gradient tensor(-7.4038e+14) tensor(-1.4354e+16)
# power tensor(4.4208e+13, grad_fn=<SelectBackward>)
# epochs: 36
# undu tensor([2.0633, 2.0633, 2.0633, 2.0633, 2.0633, 2.0633, 2.0633, 2.0633, 2.0633,
#         2.0633, 2.0633, 2.0623, 2.0593, 2.0543, 2.0473, 2.0383, 2.0273, 2.0143,
#         1.9993, 1.9823], grad_fn=<CatBackward>)
# gradient tensor(2.9698e+15) tensor(-1.1524e+15)
# power tensor(4.0368e+13, grad_fn=<SelectBackward>)
# epochs: 37
# undu tensor([2.0336, 2.0336, 2.0336, 2.0336, 2.0336, 2.0336, 2.0336, 2.0336, 2.0336,
#         2.0336, 2.0336, 2.0326, 2.0296, 2.0246, 2.0176, 2.0086, 1.9976, 1.9846,
#         1.9696, 1.9526], grad_fn=<CatBackward>)
# gradient tensor(-3.4048e+15) tensor(1.4701e+17)
# power tensor(4.3936e+13, grad_fn=<SelectBackward>)
# epochs: 38
# undu tensor([2.0676, 2.0676, 2.0676, 2.0676, 2.0676, 2.0676, 2.0676, 2.0676, 2.0676,
#         2.0676, 2.0676, 2.0666, 2.0636, 2.0586, 2.0516, 2.0426, 2.0316, 2.0186,
#         2.0036, 1.9866], grad_fn=<CatBackward>)
# gradient tensor(-1.0961e+15) tensor(8.5018e+17)
# power tensor(4.2578e+13, grad_fn=<SelectBackward>)
# epochs: 39
# undu tensor([2.0786, 2.0786, 2.0786, 2.0786, 2.0786, 2.0786, 2.0786, 2.0786, 2.0786,
#         2.0786, 2.0786, 2.0776, 2.0746, 2.0696, 2.0626, 2.0536, 2.0426, 2.0296,
#         2.0146, 1.9976], grad_fn=<CatBackward>)
# gradient tensor(7.2463e+15) tensor(7.4532e+17)
# power tensor(4.4646e+13, grad_fn=<SelectBackward>)
# epochs: 40
# undu tensor([2.0061, 2.0061, 2.0061, 2.0061, 2.0061, 2.0061, 2.0061, 2.0061, 2.0061,
#         2.0061, 2.0061, 2.0051, 2.0021, 1.9971, 1.9901, 1.9811, 1.9701, 1.9571,
#         1.9421, 1.9251], grad_fn=<CatBackward>)
# gradient tensor(3.7165e+15) tensor(-3.1937e+17)
# power tensor(4.0867e+13, grad_fn=<SelectBackward>)
# epochs: 41
# undu tensor([1.9690, 1.9690, 1.9690, 1.9690, 1.9690, 1.9690, 1.9690, 1.9690, 1.9690,
#         1.9690, 1.9690, 1.9680, 1.9650, 1.9600, 1.9530, 1.9440, 1.9330, 1.9200,
#         1.9050, 1.8880], grad_fn=<CatBackward>)
# gradient tensor(2.0832e+15) tensor(8.3281e+17)
# power tensor(3.8155e+13, grad_fn=<SelectBackward>)
# epochs: 42
# undu tensor([1.9481, 1.9481, 1.9481, 1.9481, 1.9481, 1.9481, 1.9481, 1.9481, 1.9481,
#         1.9481, 1.9481, 1.9471, 1.9441, 1.9391, 1.9321, 1.9231, 1.9121, 1.8991,
#         1.8841, 1.8671], grad_fn=<CatBackward>)
# gradient tensor(-9.6544e+14) tensor(-1.0100e+18)
# power tensor(4.0584e+13, grad_fn=<SelectBackward>)
# epochs: 43
# undu tensor([1.9578, 1.9578, 1.9578, 1.9578, 1.9578, 1.9578, 1.9578, 1.9578, 1.9578,
#         1.9578, 1.9578, 1.9568, 1.9538, 1.9488, 1.9418, 1.9328, 1.9218, 1.9088,
#         1.8938, 1.8768], grad_fn=<CatBackward>)
# gradient tensor(7.9206e+14) tensor(6.7259e+17)
# power tensor(3.6679e+13, grad_fn=<SelectBackward>)
# epochs: 44
# undu tensor([1.9499, 1.9499, 1.9499, 1.9499, 1.9499, 1.9499, 1.9499, 1.9499, 1.9499,
#         1.9499, 1.9499, 1.9489, 1.9459, 1.9409, 1.9339, 1.9249, 1.9139, 1.9009,
#         1.8859, 1.8689], grad_fn=<CatBackward>)
# gradient tensor(1.3894e+15) tensor(6.6138e+17)
# power tensor(4.1819e+13, grad_fn=<SelectBackward>)
# epochs: 45
# undu tensor([1.9360, 1.9360, 1.9360, 1.9360, 1.9360, 1.9360, 1.9360, 1.9360, 1.9360,
#         1.9360, 1.9360, 1.9350, 1.9320, 1.9270, 1.9200, 1.9110, 1.9000, 1.8870,
#         1.8720, 1.8550], grad_fn=<CatBackward>)
# gradient tensor(3.8186e+15) tensor(5.5243e+17)
# power tensor(4.4897e+13, grad_fn=<SelectBackward>)
# epochs: 46
# undu tensor([1.8978, 1.8978, 1.8978, 1.8978, 1.8978, 1.8978, 1.8978, 1.8978, 1.8978,
#         1.8978, 1.8978, 1.8968, 1.8938, 1.8888, 1.8818, 1.8728, 1.8618, 1.8488,
#         1.8338, 1.8168], grad_fn=<CatBackward>)
# gradient tensor(2.4593e+15) tensor(4.8288e+17)
# power tensor(4.7870e+13, grad_fn=<SelectBackward>)
# epochs: 47
# undu tensor([1.8732, 1.8732, 1.8732, 1.8732, 1.8732, 1.8732, 1.8732, 1.8732, 1.8732,
#         1.8732, 1.8732, 1.8722, 1.8692, 1.8642, 1.8572, 1.8482, 1.8372, 1.8242,
#         1.8092, 1.7922], grad_fn=<CatBackward>)
# gradient tensor(-3.1256e+15) tensor(-1.2529e+18)
# power tensor(5.0164e+13, grad_fn=<SelectBackward>)
# epochs: 48
# undu tensor([1.9044, 1.9044, 1.9044, 1.9044, 1.9044, 1.9044, 1.9044, 1.9044, 1.9044,
#         1.9044, 1.9044, 1.9034, 1.9004, 1.8954, 1.8884, 1.8794, 1.8684, 1.8554,
#         1.8404, 1.8234], grad_fn=<CatBackward>)
# gradient tensor(1.9822e+15) tensor(-5.4182e+17)
# power tensor(4.9975e+13, grad_fn=<SelectBackward>)
# epochs: 49
# undu tensor([1.8846, 1.8846, 1.8846, 1.8846, 1.8846, 1.8846, 1.8846, 1.8846, 1.8846,
#         1.8846, 1.8846, 1.8836, 1.8806, 1.8756, 1.8686, 1.8596, 1.8486, 1.8356,
#         1.8206, 1.8036], grad_fn=<CatBackward>)
# gradient tensor(-7.7962e+15) tensor(5.4200e+17)
# power tensor(4.9974e+13, grad_fn=<SelectBackward>)
# epochs: 50
# undu tensor([1.9626, 1.9626, 1.9626, 1.9626, 1.9626, 1.9626, 1.9626, 1.9626, 1.9626,
#         1.9626, 1.9626, 1.9616, 1.9586, 1.9536, 1.9466, 1.9376, 1.9266, 1.9136,
#         1.8986, 1.8816], grad_fn=<CatBackward>)
# gradient tensor(9.5301e+13) tensor(3.3835e+17)
# power tensor(4.2504e+13, grad_fn=<SelectBackward>)
# epochs: 51
# undu tensor([1.9616, 1.9616, 1.9616, 1.9616, 1.9616, 1.9616, 1.9616, 1.9616, 1.9616,
#         1.9616, 1.9616, 1.9606, 1.9576, 1.9526, 1.9456, 1.9366, 1.9256, 1.9126,
#         1.8976, 1.8806], grad_fn=<CatBackward>)
# gradient tensor(-3.4691e+14) tensor(-1.4614e+18)
# power tensor(4.2384e+13, grad_fn=<SelectBackward>)
# epochs: 52
# undu tensor([1.9651, 1.9651, 1.9651, 1.9651, 1.9651, 1.9651, 1.9651, 1.9651, 1.9651,
#         1.9651, 1.9651, 1.9641, 1.9611, 1.9561, 1.9491, 1.9401, 1.9291, 1.9161,
#         1.9011, 1.8841], grad_fn=<CatBackward>)
# gradient tensor(-2.7844e+15) tensor(-4.7871e+17)
# power tensor(3.9992e+13, grad_fn=<SelectBackward>)
# epochs: 53
# undu tensor([1.9929, 1.9929, 1.9929, 1.9929, 1.9929, 1.9929, 1.9929, 1.9929, 1.9929,
#         1.9929, 1.9929, 1.9919, 1.9889, 1.9839, 1.9769, 1.9679, 1.9569, 1.9439,
#         1.9289, 1.9119], grad_fn=<CatBackward>)
# gradient tensor(-2.7822e+15) tensor(-9.1430e+16)
# power tensor(4.0305e+13, grad_fn=<SelectBackward>)
# epochs: 54
# undu tensor([2.0208, 2.0208, 2.0208, 2.0208, 2.0208, 2.0208, 2.0208, 2.0208, 2.0208,
#         2.0208, 2.0208, 2.0198, 2.0168, 2.0118, 2.0048, 1.9958, 1.9848, 1.9718,
#         1.9568, 1.9398], grad_fn=<CatBackward>)
# gradient tensor(6.6105e+15) tensor(7.9602e+17)
# power tensor(4.2386e+13, grad_fn=<SelectBackward>)
# epochs: 55
# undu tensor([1.9547, 1.9547, 1.9547, 1.9547, 1.9547, 1.9547, 1.9547, 1.9547, 1.9547,
#         1.9547, 1.9547, 1.9537, 1.9507, 1.9457, 1.9387, 1.9297, 1.9187, 1.9057,
#         1.8907, 1.8737], grad_fn=<CatBackward>)
# gradient tensor(-2.0854e+15) tensor(-8.7053e+17)
# power tensor(3.9065e+13, grad_fn=<SelectBackward>)
# epochs: 56
# undu tensor([1.9755, 1.9755, 1.9755, 1.9755, 1.9755, 1.9755, 1.9755, 1.9755, 1.9755,
#         1.9755, 1.9755, 1.9745, 1.9715, 1.9665, 1.9595, 1.9505, 1.9395, 1.9265,
#         1.9115, 1.8945], grad_fn=<CatBackward>)
# gradient tensor(-1.7114e+15) tensor(-5.6120e+17)
# power tensor(4.1845e+13, grad_fn=<SelectBackward>)
# epochs: 57
# undu tensor([1.9926, 1.9926, 1.9926, 1.9926, 1.9926, 1.9926, 1.9926, 1.9926, 1.9926,
#         1.9926, 1.9926, 1.9916, 1.9886, 1.9836, 1.9766, 1.9676, 1.9566, 1.9436,
#         1.9286, 1.9116], grad_fn=<CatBackward>)
# gradient tensor(4.4280e+15) tensor(-2.8761e+17)
# power tensor(4.2978e+13, grad_fn=<SelectBackward>)
# epochs: 58
# undu tensor([1.9483, 1.9483, 1.9483, 1.9483, 1.9483, 1.9483, 1.9483, 1.9483, 1.9483,
#         1.9483, 1.9483, 1.9473, 1.9443, 1.9393, 1.9323, 1.9233, 1.9123, 1.8993,
#         1.8843, 1.8673], grad_fn=<CatBackward>)
# gradient tensor(4.4489e+15) tensor(1.6288e+18)
# power tensor(4.2114e+13, grad_fn=<SelectBackward>)
# epochs: 59
# undu tensor([1.9039, 1.9039, 1.9039, 1.9039, 1.9039, 1.9039, 1.9039, 1.9039, 1.9039,
#         1.9039, 1.9039, 1.9029, 1.8999, 1.8949, 1.8879, 1.8789, 1.8679, 1.8549,
#         1.8399, 1.8229], grad_fn=<CatBackward>)
# gradient tensor(-1.1247e+16) tensor(-1.7730e+17)
# power tensor(5.1891e+13, grad_fn=<SelectBackward>)
# epochs: 60
# undu tensor([2.0163, 2.0163, 2.0163, 2.0163, 2.0163, 2.0163, 2.0163, 2.0163, 2.0163,
#         2.0163, 2.0163, 2.0153, 2.0123, 2.0073, 2.0003, 1.9913, 1.9803, 1.9673,
#         1.9523, 1.9353], grad_fn=<CatBackward>)
# gradient tensor(1.2243e+15) tensor(5.2828e+17)
# power tensor(4.4490e+13, grad_fn=<SelectBackward>)
# epochs: 61
# undu tensor([2.0041, 2.0041, 2.0041, 2.0041, 2.0041, 2.0041, 2.0041, 2.0041, 2.0041,
#         2.0041, 2.0041, 2.0031, 2.0001, 1.9951, 1.9881, 1.9791, 1.9681, 1.9551,
#         1.9401, 1.9231], grad_fn=<CatBackward>)
# gradient tensor(-4.7354e+15) tensor(-1.6221e+18)
# power tensor(4.7020e+13, grad_fn=<SelectBackward>)
# epochs: 62
# undu tensor([2.0514, 2.0514, 2.0514, 2.0514, 2.0514, 2.0514, 2.0514, 2.0514, 2.0514,
#         2.0514, 2.0514, 2.0504, 2.0474, 2.0424, 2.0354, 2.0264, 2.0154, 2.0024,
#         1.9874, 1.9704], grad_fn=<CatBackward>)
# gradient tensor(3.0025e+15) tensor(-1.4103e+18)
# power tensor(4.5320e+13, grad_fn=<SelectBackward>)
# epochs: 63
# undu tensor([2.0214, 2.0214, 2.0214, 2.0214, 2.0214, 2.0214, 2.0214, 2.0214, 2.0214,
#         2.0214, 2.0214, 2.0204, 2.0174, 2.0124, 2.0054, 1.9964, 1.9854, 1.9724,
#         1.9574, 1.9404], grad_fn=<CatBackward>)
# gradient tensor(-9.5256e+14) tensor(1.0793e+18)
# power tensor(4.2335e+13, grad_fn=<SelectBackward>)
# epochs: 64
# undu tensor([2.0309, 2.0309, 2.0309, 2.0309, 2.0309, 2.0309, 2.0309, 2.0309, 2.0309,
#         2.0309, 2.0309, 2.0299, 2.0269, 2.0219, 2.0149, 2.0059, 1.9949, 1.9819,
#         1.9669, 1.9499], grad_fn=<CatBackward>)
# gradient tensor(-8.9476e+14) tensor(-4.7356e+17)
# power tensor(4.4378e+13, grad_fn=<SelectBackward>)
# epochs: 65
# undu tensor([2.0399, 2.0399, 2.0399, 2.0399, 2.0399, 2.0399, 2.0399, 2.0399, 2.0399,
#         2.0399, 2.0399, 2.0389, 2.0359, 2.0309, 2.0239, 2.0149, 2.0039, 1.9909,
#         1.9759, 1.9589], grad_fn=<CatBackward>)
# gradient tensor(2.4828e+15) tensor(8.1323e+17)
# power tensor(4.4804e+13, grad_fn=<SelectBackward>)
# epochs: 66
# undu tensor([2.0151, 2.0151, 2.0151, 2.0151, 2.0151, 2.0151, 2.0151, 2.0151, 2.0151,
#         2.0151, 2.0151, 2.0141, 2.0111, 2.0061, 1.9991, 1.9901, 1.9791, 1.9661,
#         1.9511, 1.9341], grad_fn=<CatBackward>)
# gradient tensor(1.0299e+15) tensor(-5.7302e+17)
# power tensor(4.4138e+13, grad_fn=<SelectBackward>)
# epochs: 67
# undu tensor([2.0048, 2.0048, 2.0048, 2.0048, 2.0048, 2.0048, 2.0048, 2.0048, 2.0048,
#         2.0048, 2.0048, 2.0038, 2.0008, 1.9958, 1.9888, 1.9798, 1.9688, 1.9558,
#         1.9408, 1.9238], grad_fn=<CatBackward>)
# gradient tensor(-5.9123e+15) tensor(-1.0687e+18)
# power tensor(4.5696e+13, grad_fn=<SelectBackward>)
# epochs: 68
# undu tensor([2.0639, 2.0639, 2.0639, 2.0639, 2.0639, 2.0639, 2.0639, 2.0639, 2.0639,
#         2.0639, 2.0639, 2.0629, 2.0599, 2.0549, 2.0479, 2.0389, 2.0279, 2.0149,
#         1.9999, 1.9829], grad_fn=<CatBackward>)
# gradient tensor(2.7440e+15) tensor(4.0695e+17)
# power tensor(3.9995e+13, grad_fn=<SelectBackward>)
# epochs: 69
# undu tensor([2.0364, 2.0364, 2.0364, 2.0364, 2.0364, 2.0364, 2.0364, 2.0364, 2.0364,
#         2.0364, 2.0364, 2.0354, 2.0324, 2.0274, 2.0204, 2.0114, 2.0004, 1.9874,
#         1.9724, 1.9554], grad_fn=<CatBackward>)
# gradient tensor(-2.4504e+15) tensor(-8.6323e+17)
# power tensor(4.4177e+13, grad_fn=<SelectBackward>)
# epochs: 70
# undu tensor([2.0609, 2.0609, 2.0609, 2.0609, 2.0609, 2.0609, 2.0609, 2.0609, 2.0609,
#         2.0609, 2.0609, 2.0599, 2.0569, 2.0519, 2.0449, 2.0359, 2.0249, 2.0119,
#         1.9969, 1.9799], grad_fn=<CatBackward>)
# gradient tensor(7.1221e+14) tensor(9.1796e+17)
# power tensor(3.9445e+13, grad_fn=<SelectBackward>)
# epochs: 71
# undu tensor([2.0538, 2.0538, 2.0538, 2.0538, 2.0538, 2.0538, 2.0538, 2.0538, 2.0538,
#         2.0538, 2.0538, 2.0528, 2.0498, 2.0448, 2.0378, 2.0288, 2.0178, 2.0048,
#         1.9898, 1.9728], grad_fn=<CatBackward>)
# gradient tensor(-1.1157e+15) tensor(1.0739e+18)
# power tensor(4.3992e+13, grad_fn=<SelectBackward>)
# epochs: 72
# undu tensor([2.0650, 2.0650, 2.0650, 2.0650, 2.0650, 2.0650, 2.0650, 2.0650, 2.0650,
#         2.0650, 2.0650, 2.0640, 2.0610, 2.0560, 2.0490, 2.0400, 2.0290, 2.0160,
#         2.0010, 1.9840], grad_fn=<CatBackward>)
# gradient tensor(3.0257e+15) tensor(5.1003e+17)
# power tensor(4.1493e+13, grad_fn=<SelectBackward>)
# epochs: 73
# undu tensor([2.0347, 2.0347, 2.0347, 2.0347, 2.0347, 2.0347, 2.0347, 2.0347, 2.0347,
#         2.0347, 2.0347, 2.0337, 2.0307, 2.0257, 2.0187, 2.0097, 1.9987, 1.9857,
#         1.9707, 1.9537], grad_fn=<CatBackward>)
# gradient tensor(-8.4346e+15) tensor(-7.2729e+17)
# power tensor(4.4879e+13, grad_fn=<SelectBackward>)
# epochs: 74
# undu tensor([2.1191, 2.1191, 2.1191, 2.1191, 2.1191, 2.1191, 2.1191, 2.1191, 2.1191,
#         2.1191, 2.1191, 2.1181, 2.1151, 2.1101, 2.1031, 2.0941, 2.0831, 2.0701,
#         2.0551, 2.0381], grad_fn=<CatBackward>)
# gradient tensor(-1.1345e+16) tensor(1.0136e+17)
# power tensor(5.1865e+13, grad_fn=<SelectBackward>)
# epochs: 75
# undu tensor([2.2325, 2.2325, 2.2325, 2.2325, 2.2325, 2.2325, 2.2325, 2.2325, 2.2325,
#         2.2325, 2.2325, 2.2315, 2.2285, 2.2235, 2.2165, 2.2075, 2.1965, 2.1835,
#         2.1685, 2.1515], grad_fn=<CatBackward>)
# gradient tensor(8.9842e+15) tensor(7.0044e+17)
# power tensor(3.9743e+13, grad_fn=<SelectBackward>)
# epochs: 76
# undu tensor([2.1427, 2.1427, 2.1427, 2.1427, 2.1427, 2.1427, 2.1427, 2.1427, 2.1427,
#         2.1427, 2.1427, 2.1417, 2.1387, 2.1337, 2.1267, 2.1177, 2.1067, 2.0937,
#         2.0787, 2.0617], grad_fn=<CatBackward>)
# gradient tensor(9.5346e+15) tensor(-7.4497e+17)
# power tensor(4.9249e+13, grad_fn=<SelectBackward>)
# epochs: 77
# undu tensor([2.0473, 2.0473, 2.0473, 2.0473, 2.0473, 2.0473, 2.0473, 2.0473, 2.0473,
#         2.0473, 2.0473, 2.0463, 2.0433, 2.0383, 2.0313, 2.0223, 2.0113, 1.9983,
#         1.9833, 1.9663], grad_fn=<CatBackward>)
# gradient tensor(5.4723e+15) tensor(-8.6517e+17)
# power tensor(3.8968e+13, grad_fn=<SelectBackward>)
# epochs: 78
# undu tensor([1.9926, 1.9926, 1.9926, 1.9926, 1.9926, 1.9926, 1.9926, 1.9926, 1.9926,
#         1.9926, 1.9926, 1.9916, 1.9886, 1.9836, 1.9766, 1.9676, 1.9566, 1.9436,
#         1.9286, 1.9116], grad_fn=<CatBackward>)
# gradient tensor(-6.1861e+14) tensor(4.9752e+17)
# power tensor(4.2887e+13, grad_fn=<SelectBackward>)
# epochs: 79
# undu tensor([1.9988, 1.9988, 1.9988, 1.9988, 1.9988, 1.9988, 1.9988, 1.9988, 1.9988,
#         1.9988, 1.9988, 1.9978, 1.9948, 1.9898, 1.9828, 1.9738, 1.9628, 1.9498,
#         1.9348, 1.9178], grad_fn=<CatBackward>)
# gradient tensor(1.4496e+14) tensor(1.5187e+18)
# power tensor(4.1983e+13, grad_fn=<SelectBackward>)
# epochs: 80
# undu tensor([1.9973, 1.9973, 1.9973, 1.9973, 1.9973, 1.9973, 1.9973, 1.9973, 1.9973,
#         1.9973, 1.9973, 1.9963, 1.9933, 1.9883, 1.9813, 1.9723, 1.9613, 1.9483,
#         1.9333, 1.9163], grad_fn=<CatBackward>)
# gradient tensor(1.7731e+15) tensor(-1.4849e+17)
# power tensor(4.2327e+13, grad_fn=<SelectBackward>)
# epochs: 81
# undu tensor([1.9796, 1.9796, 1.9796, 1.9796, 1.9796, 1.9796, 1.9796, 1.9796, 1.9796,
#         1.9796, 1.9796, 1.9786, 1.9756, 1.9706, 1.9636, 1.9546, 1.9436, 1.9306,
#         1.9156, 1.8986], grad_fn=<CatBackward>)
# gradient tensor(-4.1529e+15) tensor(-1.9900e+18)
# power tensor(4.2456e+13, grad_fn=<SelectBackward>)
# epochs: 82
# undu tensor([2.0211, 2.0211, 2.0211, 2.0211, 2.0211, 2.0211, 2.0211, 2.0211, 2.0211,
#         2.0211, 2.0211, 2.0201, 2.0171, 2.0121, 2.0051, 1.9961, 1.9851, 1.9721,
#         1.9571, 1.9401], grad_fn=<CatBackward>)
# gradient tensor(6.0267e+14) tensor(-5.0519e+17)
# power tensor(4.2457e+13, grad_fn=<SelectBackward>)
# epochs: 83
# undu tensor([2.0151, 2.0151, 2.0151, 2.0151, 2.0151, 2.0151, 2.0151, 2.0151, 2.0151,
#         2.0151, 2.0151, 2.0141, 2.0111, 2.0061, 1.9991, 1.9901, 1.9791, 1.9661,
#         1.9511, 1.9341], grad_fn=<CatBackward>)
# gradient tensor(-4.9029e+15) tensor(-1.0124e+18)
# power tensor(4.4406e+13, grad_fn=<SelectBackward>)
# epochs: 84
# undu tensor([2.0641, 2.0641, 2.0641, 2.0641, 2.0641, 2.0641, 2.0641, 2.0641, 2.0641,
#         2.0641, 2.0641, 2.0631, 2.0601, 2.0551, 2.0481, 2.0391, 2.0281, 2.0151,
#         2.0001, 1.9831], grad_fn=<CatBackward>)
# gradient tensor(9.9643e+13) tensor(1.0419e+18)
# power tensor(4.0344e+13, grad_fn=<SelectBackward>)
# epochs: 85
# undu tensor([2.0631, 2.0631, 2.0631, 2.0631, 2.0631, 2.0631, 2.0631, 2.0631, 2.0631,
#         2.0631, 2.0631, 2.0621, 2.0591, 2.0541, 2.0471, 2.0381, 2.0271, 2.0141,
#         1.9991, 1.9821], grad_fn=<CatBackward>)
# gradient tensor(3.0835e+15) tensor(5.4251e+17)
# power tensor(4.0510e+13, grad_fn=<SelectBackward>)
# epochs: 86
# undu tensor([2.0323, 2.0323, 2.0323, 2.0323, 2.0323, 2.0323, 2.0323, 2.0323, 2.0323,
#         2.0323, 2.0323, 2.0313, 2.0283, 2.0233, 2.0163, 2.0073, 1.9963, 1.9833,
#         1.9683, 1.9513], grad_fn=<CatBackward>)
# gradient tensor(-2.7775e+15) tensor(-1.2230e+18)
# power tensor(4.2775e+13, grad_fn=<SelectBackward>)
# epochs: 87
# undu tensor([2.0601, 2.0601, 2.0601, 2.0601, 2.0601, 2.0601, 2.0601, 2.0601, 2.0601,
#         2.0601, 2.0601, 2.0591, 2.0561, 2.0511, 2.0441, 2.0351, 2.0241, 2.0111,
#         1.9961, 1.9791], grad_fn=<CatBackward>)
# gradient tensor(-3.2501e+15) tensor(7.5950e+16)
# power tensor(4.0502e+13, grad_fn=<SelectBackward>)
# epochs: 88
# undu tensor([2.0926, 2.0926, 2.0926, 2.0926, 2.0926, 2.0926, 2.0926, 2.0926, 2.0926,
#         2.0926, 2.0926, 2.0916, 2.0886, 2.0836, 2.0766, 2.0676, 2.0566, 2.0436,
#         2.0286, 2.0116], grad_fn=<CatBackward>)
# gradient tensor(-8.3977e+15) tensor(1.6176e+17)
# power tensor(4.8846e+13, grad_fn=<SelectBackward>)
# epochs: 89
# undu tensor([2.1766, 2.1766, 2.1766, 2.1766, 2.1766, 2.1766, 2.1766, 2.1766, 2.1766,
#         2.1766, 2.1766, 2.1756, 2.1726, 2.1676, 2.1606, 2.1516, 2.1406, 2.1276,
#         2.1126, 2.0956], grad_fn=<CatBackward>)
# gradient tensor(8.8182e+15) tensor(4.3637e+17)
# power tensor(3.6823e+13, grad_fn=<SelectBackward>)
# epochs: 90
# undu tensor([2.0884, 2.0884, 2.0884, 2.0884, 2.0884, 2.0884, 2.0884, 2.0884, 2.0884,
#         2.0884, 2.0884, 2.0874, 2.0844, 2.0794, 2.0724, 2.0634, 2.0524, 2.0394,
#         2.0244, 2.0074], grad_fn=<CatBackward>)
# gradient tensor(-5.7257e+15) tensor(-7.7134e+17)
# power tensor(4.3406e+13, grad_fn=<SelectBackward>)
# epochs: 91
# undu tensor([2.1456, 2.1456, 2.1456, 2.1456, 2.1456, 2.1456, 2.1456, 2.1456, 2.1456,
#         2.1456, 2.1456, 2.1446, 2.1416, 2.1366, 2.1296, 2.1206, 2.1096, 2.0966,
#         2.0816, 2.0646], grad_fn=<CatBackward>)
# gradient tensor(-4.4297e+14) tensor(1.8350e+17)
# power tensor(4.4831e+13, grad_fn=<SelectBackward>)
# epochs: 92
# undu tensor([2.1501, 2.1501, 2.1501, 2.1501, 2.1501, 2.1501, 2.1501, 2.1501, 2.1501,
#         2.1501, 2.1501, 2.1491, 2.1461, 2.1411, 2.1341, 2.1251, 2.1141, 2.1011,
#         2.0861, 2.0691], grad_fn=<CatBackward>)
# gradient tensor(2.9714e+15) tensor(5.9815e+17)
# power tensor(4.5961e+13, grad_fn=<SelectBackward>)
# epochs: 93
# undu tensor([2.1204, 2.1204, 2.1204, 2.1204, 2.1204, 2.1204, 2.1204, 2.1204, 2.1204,
#         2.1204, 2.1204, 2.1194, 2.1164, 2.1114, 2.1044, 2.0954, 2.0844, 2.0714,
#         2.0564, 2.0394], grad_fn=<CatBackward>)
# gradient tensor(-5.9598e+15) tensor(-9.5652e+17)
# power tensor(4.8235e+13, grad_fn=<SelectBackward>)
# epochs: 94
# undu tensor([2.1800, 2.1800, 2.1800, 2.1800, 2.1800, 2.1800, 2.1800, 2.1800, 2.1800,
#         2.1800, 2.1800, 2.1790, 2.1760, 2.1710, 2.1640, 2.1550, 2.1440, 2.1310,
#         2.1160, 2.0990], grad_fn=<CatBackward>)
# gradient tensor(5.6689e+15) tensor(1.4927e+17)
# power tensor(3.4435e+13, grad_fn=<SelectBackward>)
# epochs: 95
# undu tensor([2.1233, 2.1233, 2.1233, 2.1233, 2.1233, 2.1233, 2.1233, 2.1233, 2.1233,
#         2.1233, 2.1233, 2.1223, 2.1193, 2.1143, 2.1073, 2.0983, 2.0873, 2.0743,
#         2.0593, 2.0423], grad_fn=<CatBackward>)
# gradient tensor(9.2661e+15) tensor(-2.3723e+17)
# power tensor(4.5415e+13, grad_fn=<SelectBackward>)
# epochs: 96
# undu tensor([2.0306, 2.0306, 2.0306, 2.0306, 2.0306, 2.0306, 2.0306, 2.0306, 2.0306,
#         2.0306, 2.0306, 2.0296, 2.0266, 2.0216, 2.0146, 2.0056, 1.9946, 1.9816,
#         1.9666, 1.9496], grad_fn=<CatBackward>)
# gradient tensor(-3.9136e+15) tensor(1.2171e+18)
# power tensor(4.4844e+13, grad_fn=<SelectBackward>)
# epochs: 97
# undu tensor([2.0697, 2.0697, 2.0697, 2.0697, 2.0697, 2.0697, 2.0697, 2.0697, 2.0697,
#         2.0697, 2.0697, 2.0687, 2.0657, 2.0607, 2.0537, 2.0447, 2.0337, 2.0207,
#         2.0057, 1.9887], grad_fn=<CatBackward>)
# gradient tensor(-4.0653e+14) tensor(1.1502e+17)
# power tensor(4.2124e+13, grad_fn=<SelectBackward>)
# epochs: 98
# undu tensor([2.0738, 2.0738, 2.0738, 2.0738, 2.0738, 2.0738, 2.0738, 2.0738, 2.0738,
#         2.0738, 2.0738, 2.0728, 2.0698, 2.0648, 2.0578, 2.0488, 2.0378, 2.0248,
#         2.0098, 1.9928], grad_fn=<CatBackward>)
# gradient tensor(-2.5834e+15) tensor(-1.7779e+18)
# power tensor(4.7073e+13, grad_fn=<SelectBackward>)
# epochs: 99
# undu tensor([2.0996, 2.0996, 2.0996, 2.0996, 2.0996, 2.0996, 2.0996, 2.0996, 2.0996,
#         2.0996, 2.0996, 2.0986, 2.0956, 2.0906, 2.0836, 2.0746, 2.0636, 2.0506,
#         2.0356, 2.0186], grad_fn=<CatBackward>)
# gradient tensor(6.6151e+15) tensor(-2.6026e+17)
# power tensor(4.4880e+13, grad_fn=<SelectBackward>)
# epochs: 100
# undu tensor([2.0335, 2.0335, 2.0335, 2.0335, 2.0335, 2.0335, 2.0335, 2.0335, 2.0335,
#         2.0335, 2.0335, 2.0325, 2.0295, 2.0245, 2.0175, 2.0085, 1.9975, 1.9845,
#         1.9695, 1.9525], grad_fn=<CatBackward>)
# gradient tensor(-8.0807e+15) tensor(-8.0789e+17)
# power tensor(4.4017e+13, grad_fn=<SelectBackward>)

# %%
plt.figure()
plt.plot(undu_K.detach().numpy())
plt.title('final taper value')
plt.figure()
plt.plot(his_FEL_power,'.-')
plt.title('output FEL power vs. epochs')
# Out:
# Text(0.5, 1.0, 'output FEL power vs. epochs')
